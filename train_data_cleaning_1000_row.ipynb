# %% [markdown]
# # Data Cleaning - First 1000 row

# %%
#Import the needed libraries
import pandas as pd

# %%
df = pd.read_csv('dataset/test_v2.csv',nrows=1000)

# %%
df.dtypes
# Out:
# channelGrouping         object
# customDimensions        object
# date                     int64
# device                  object
# fullVisitorId           uint64
# geoNetwork              object
# hits                    object
# socialEngagementType    object
# totals                  object
# trafficSource           object
# visitId                  int64
# visitNumber              int64
# visitStartTime           int64
# dtype: object

# %% [markdown]
# **Data Definition**
#
# * **fullVisitorId** - A unique identifier for each user of the Google Merchandise Store.
# * **channelGrouping** - The channel via which the user came to the Store.
# * **date** - The date on which the user visited the Store.
# * **device** - The specifications for the device used to access the Store.
# * **geoNetwork** - This section contains information about the geography of the user.
# * **socialEngagementType** - Engagement type, either "Socially Engaged" or "Not Socially Engaged".
# * **totals** - This section contains aggregate values across the session.
# * **trafficSource** - This section contains information about the Traffic Source from which the session originated.
# * **visitId** - An identifier for this session. This is part of the value usually stored as the _utmb cookie. This is only unique to the user. For a completely unique ID, you should use a combination of fullVisitorId and visitId.
# * **visitNumber** - The session number for this user. If this is the first session, then this is set to 1.
# * **visitStartTime** - The timestamp .
# * **hits** - This row and nested fields are populated for any and all types of hits. Provides a record of all page visits.
# * **customDimensions** - This section contains any user-level or session-level custom dimensions that are set for a session. This is a repeated field and has an entry for each dimension that is set.
# * **totals** - This set of columns mostly includes high-level aggregate data.

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  7460955084541987166
# 1  {"browser": "Chrome", "browserVersion": "not a...   460252456180441002
# 2  {"browser": "Chrome", "browserVersion": "not a...  3461808543879602873
# 3  {"browser": "Chrome", "browserVersion": "not a...   975129477712150630
# 4  {"browser": "Internet Explorer", "browserVersi...  8381672768065729990
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Souther...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "4", "pageviews": "3",...
# 1  {"visits": "1", "hits": "4", "pageviews": "3",...
# 2  {"visits": "1", "hits": "4", "pageviews": "3",...
# 3  {"visits": "1", "hits": "5", "pageviews": "4",...
# 4  {"visits": "1", "hits": "5", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"referralPath": "(not set)", "campaign": "(no...  1526099341            2
# 1  {"referralPath": "(not set)", "campaign": "(no...  1526064483          166
# 2  {"referralPath": "(not set)", "campaign": "(no...  1526067157            2
# 3  {"referralPath": "(not set)", "campaign": "(no...  1526107551            4
# 4  {"referralPath": "(not set)", "campaign": "(no...  1526060254            1
#
#    visitStartTime
# 0      1526099341
# 1      1526064483
# 2      1526067157
# 3      1526107551
# 4      1526060254

# %%
df.columns
# Out:
# Index(['channelGrouping', 'customDimensions', 'date', 'device',
#        'fullVisitorId', 'geoNetwork', 'hits', 'socialEngagementType', 'totals',
#        'trafficSource', 'visitId', 'visitNumber', 'visitStartTime'],
#       dtype='object')

# %% [markdown]
# From the first glance, we can see that there are a value list in some column. We can try to seperate those into another columns.

# %% [markdown]
# First, we can see with the **customDimensions** columns that it's a JSON type but it's in a list. So we have to flatten out the list first

# %% [markdown]
# There are some way we can use, we can use the manual way :

# %%
#Get the value in index
index = {}
for i in range(len(df['customDimensions'])):
    if df.loc[i,'customDimensions']=="[]":
        index_value = "null"
    else:         
        index_value = df.loc[i,'customDimensions'].split(" 'value':")[0].replace("[{'index': ","").replace("'","").replace(",","")
    index[i]=index_value

# %%
#Get the value in value
value = {}
for i in range(len(df['customDimensions'])):
    if df.loc[i,'customDimensions']=="[]":
        value_value = "null"
    else:         
        value_value = df.loc[i,'customDimensions'].split("[{'index': '4', 'value': ")[1].replace("'}]","").replace("'","")
    value[i]=value_value

# %% [markdown]
# or using json libraries

# %%
import json
customDimensions={}
for j in json.loads(df.loc[0,'customDimensions'].replace("[","").replace("]","").replace("'",'"')).keys():
    col_val = {}
    for i in range(len(df)):
        if df.loc[i,'customDimensions']=="[]":
            value = "null"
        else:
            value = df.loc[i,'customDimensions'].replace("[","").replace("]","").replace("'",'"')
            value = json.loads(value)
            value = value[j]
        col_val[i]=value
    customDimensions[j]=col_val

# %%
for i in customDimensions.keys():
    a = "customDimensions_"+i
    df[a] = pd.DataFrame.from_dict(customDimensions[i],orient='index')

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  7460955084541987166
# 1  {"browser": "Chrome", "browserVersion": "not a...   460252456180441002
# 2  {"browser": "Chrome", "browserVersion": "not a...  3461808543879602873
# 3  {"browser": "Chrome", "browserVersion": "not a...   975129477712150630
# 4  {"browser": "Internet Explorer", "browserVersi...  8381672768065729990
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Souther...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "4", "pageviews": "3",...
# 1  {"visits": "1", "hits": "4", "pageviews": "3",...
# 2  {"visits": "1", "hits": "4", "pageviews": "3",...
# 3  {"visits": "1", "hits": "5", "pageviews": "4",...
# 4  {"visits": "1", "hits": "5", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"referralPath": "(not set)", "campaign": "(no...  1526099341            2
# 1  {"referralPath": "(not set)", "campaign": "(no...  1526064483          166
# 2  {"referralPath": "(not set)", "campaign": "(no...  1526067157            2
# 3  {"referralPath": "(not set)", "campaign": "(no...  1526107551            4
# 4  {"referralPath": "(not set)", "campaign": "(no...  1526060254            1
#
#    visitStartTime customDimensions_index customDimensions_value
# 0      1526099341                      4                   APAC
# 1      1526064483                      4          North America
# 2      1526067157                      4          North America
# 3      1526107551                      4          North America
# 4      1526060254                      4          North America

# %% [markdown]
# Okay so we're done with the first column, now we can do the same thing for device, geoNetwork, hits, totals, and trafficSource. I made a function to change the format from json and then a function to change the dictionary into dataframe and enter the values into a new column in the original dataset

# %% [markdown]
# **Changing data from json type function**

# %%
def change_json(df,column):
    import json
    sub_column={}
    if df.loc[0,column][0]=="[":
        data = df.loc[0,column].replace("[","").replace("]","").replace("'",'"')
    else:
        data = df.loc[0,column]
    for j in json.loads(data).keys():
        col_val = {}
        for i in range(len(df)):
            if df.loc[i,column]=="[]":
                value = "null"
            else:
                value = json.loads(df.loc[i,column])
                value = value[j]
            col_val[i]=value
        sub_column[j]=col_val
    return sub_column

# %% [markdown]
# **From dictionary to new column in dataset**

# %%
def dict_to_df(column):
    for i in column.keys():
        df[i] = pd.DataFrame.from_dict(column[i],orient='index')

# %%
device = change_json(df,'device')
dict_to_df(device)

# %%
pd.set_option('display.max_columns',100)
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  7460955084541987166
# 1  {"browser": "Chrome", "browserVersion": "not a...   460252456180441002
# 2  {"browser": "Chrome", "browserVersion": "not a...  3461808543879602873
# 3  {"browser": "Chrome", "browserVersion": "not a...   975129477712150630
# 4  {"browser": "Internet Explorer", "browserVersi...  8381672768065729990
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Souther...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "4", "pageviews": "3",...
# 1  {"visits": "1", "hits": "4", "pageviews": "3",...
# 2  {"visits": "1", "hits": "4", "pageviews": "3",...
# 3  {"visits": "1", "hits": "5", "pageviews": "4",...
# 4  {"visits": "1", "hits": "5", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"referralPath": "(not set)", "campaign": "(no...  1526099341            2
# 1  {"referralPath": "(not set)", "campaign": "(no...  1526064483          166
# 2  {"referralPath": "(not set)", "campaign": "(no...  1526067157            2
# 3  {"referralPath": "(not set)", "campaign": "(no...  1526107551            4
# 4  {"referralPath": "(not set)", "campaign": "(no...  1526060254            1
#
#    visitStartTime customDimensions_index customDimensions_value  \
# 0      1526099341                      4                   APAC
# 1      1526064483                      4          North America
# 2      1526067157                      4          North America
# 3      1526107551                      4          North America
# 4      1526060254                      4          North America
#
#              browser                 browserVersion  \
# 0             Chrome  not available in demo dataset
# 1             Chrome  not available in demo dataset
# 2             Chrome  not available in demo dataset
# 3             Chrome  not available in demo dataset
# 4  Internet Explorer  not available in demo dataset
#
#                      browserSize operatingSystem  \
# 0  not available in demo dataset         Android
# 1  not available in demo dataset       Macintosh
# 2  not available in demo dataset       Chrome OS
# 3  not available in demo dataset             iOS
# 4  not available in demo dataset         Windows
#
#           operatingSystemVersion  isMobile           mobileDeviceBranding  \
# 0  not available in demo dataset      True  not available in demo dataset
# 1  not available in demo dataset     False  not available in demo dataset
# 2  not available in demo dataset     False  not available in demo dataset
# 3  not available in demo dataset      True  not available in demo dataset
# 4  not available in demo dataset      True  not available in demo dataset
#
#                mobileDeviceModel            mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 mobileDeviceInfo      mobileDeviceMarketingName  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     flashVersion                       language  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     screenColors               screenResolution deviceCategory
# 0  not available in demo dataset  not available in demo dataset         mobile
# 1  not available in demo dataset  not available in demo dataset        desktop
# 2  not available in demo dataset  not available in demo dataset        desktop
# 3  not available in demo dataset  not available in demo dataset         mobile
# 4  not available in demo dataset  not available in demo dataset         tablet

# %% [markdown]
# Now we do the rest of the variables. First lets do the same for geoNetwork

# %%
#geoNetwork
val = change_json(df,'geoNetwork')
dict_to_df(val)

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  7460955084541987166
# 1  {"browser": "Chrome", "browserVersion": "not a...   460252456180441002
# 2  {"browser": "Chrome", "browserVersion": "not a...  3461808543879602873
# 3  {"browser": "Chrome", "browserVersion": "not a...   975129477712150630
# 4  {"browser": "Internet Explorer", "browserVersi...  8381672768065729990
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Souther...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "4", "pageviews": "3",...
# 1  {"visits": "1", "hits": "4", "pageviews": "3",...
# 2  {"visits": "1", "hits": "4", "pageviews": "3",...
# 3  {"visits": "1", "hits": "5", "pageviews": "4",...
# 4  {"visits": "1", "hits": "5", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"referralPath": "(not set)", "campaign": "(no...  1526099341            2
# 1  {"referralPath": "(not set)", "campaign": "(no...  1526064483          166
# 2  {"referralPath": "(not set)", "campaign": "(no...  1526067157            2
# 3  {"referralPath": "(not set)", "campaign": "(no...  1526107551            4
# 4  {"referralPath": "(not set)", "campaign": "(no...  1526060254            1
#
#    visitStartTime customDimensions_index customDimensions_value  \
# 0      1526099341                      4                   APAC
# 1      1526064483                      4          North America
# 2      1526067157                      4          North America
# 3      1526107551                      4          North America
# 4      1526060254                      4          North America
#
#              browser                 browserVersion  \
# 0             Chrome  not available in demo dataset
# 1             Chrome  not available in demo dataset
# 2             Chrome  not available in demo dataset
# 3             Chrome  not available in demo dataset
# 4  Internet Explorer  not available in demo dataset
#
#                      browserSize operatingSystem  \
# 0  not available in demo dataset         Android
# 1  not available in demo dataset       Macintosh
# 2  not available in demo dataset       Chrome OS
# 3  not available in demo dataset             iOS
# 4  not available in demo dataset         Windows
#
#           operatingSystemVersion  isMobile           mobileDeviceBranding  \
# 0  not available in demo dataset      True  not available in demo dataset
# 1  not available in demo dataset     False  not available in demo dataset
# 2  not available in demo dataset     False  not available in demo dataset
# 3  not available in demo dataset      True  not available in demo dataset
# 4  not available in demo dataset      True  not available in demo dataset
#
#                mobileDeviceModel            mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 mobileDeviceInfo      mobileDeviceMarketingName  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     flashVersion                       language  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     screenColors               screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   deviceCategory continent      subContinent        country  \
# 0         mobile      Asia     Southern Asia          India
# 1        desktop  Americas  Northern America  United States
# 2        desktop  Americas  Northern America  United States
# 3         mobile  Americas  Northern America  United States
# 4         tablet  Americas  Northern America  United States
#
#                           region                              metro  \
# 0                          Delhi                          (not set)
# 1                     California  San Francisco-Oakland-San Jose CA
# 2  not available in demo dataset      not available in demo dataset
# 3                          Texas                         Houston TX
# 4                     California                     Los Angeles CA
#
#                             city                         cityId  \
# 0                      (not set)  not available in demo dataset
# 1                  San Francisco  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3                        Houston  not available in demo dataset
# 4                         Irvine  not available in demo dataset
#
#              networkDomain                       latitude  \
# 0          unknown.unknown  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2  onlinecomputerworks.com  not available in demo dataset
# 3                (not set)  not available in demo dataset
# 4                      com  not available in demo dataset
#
#                        longitude                networkLocation
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset

# %%
val = change_json(df,'hits')
dict_to_df(val)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-17-5eba6f16b14e> in <module>
# ----> 1 val = change_json(df,'hits')
#       2 dict_to_df(val)
#
# <ipython-input-11-4b51f574b392> in change_json(df, column)
#       6     else:
#       7         data = df.loc[0,column]
# ----> 8     for j in json.loads(data).keys():
#       9         col_val = {}
#      10         for i in range(len(df)):
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 80 (char 79)

# %% [markdown]
# We can see when we're entering the hits column into the function, it gives an error. We can see that this hits column have a nested dictionary. Looks like we cannot convert the column to json with json.loads so I tried to do in the manual way

# %% [markdown]
# 1. get all column name because each index have different length -> that what makes it error
# -> get the most length out of all index -> note that there are possibilities the next 1000 row of data have larger index
# -> or to stay safe, get the least length so there will not be a lot of missing value
# 2. after that, match/search the value that match the column name

# %%
df.loc[2,'hits'].replace("[","").replace("]","").replace("'",'"')
# Out:
# '{"hitNumber": "1", "time": "0", "hour": "12", "minute": "32", "isInteraction": True, "referer": "https://www.google.com/", "page": {"pagePath": "/google+redesign/apparel/womens/womens+t+shirts", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Women"s T-Shirts | Apparel | Google Merchandise Store", "pagePathLevel1": "/google+redesign/", "pagePathLevel2": "/apparel/", "pagePathLevel3": "/womens/", "pagePathLevel4": "/womens+t+shirts"}, "transaction": {"currencyCode": "USD"}, "item": {"currencyCode": "USD"}, "appInfo": {"screenName": "shop.googlemerchandisestore.com/google+redesign/apparel/womens/womens+t+shirts", "landingScreenName": "shop.googlemerchandisestore.com/google+redesign/apparel/womens/womens+t+shirts", "exitScreenName": "shop.googlemerchandisestore.com/google+redesign/apparel/womens", "screenDepth": "0"}, "exceptionInfo": {"isFatal": True}, "eventInfo": {"eventCategory": "Enhanced Ecommerce", "eventAction": "Add to Cart"}, "product": {"productSKU": "GGOEGXXX0903", "v2ProductName": "Google Tee White", "v2ProductCategory": "Home/Apparel/Women"s/Women"s-T-Shirts/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "21990000", "localProductPrice": "21990000", "productQuantity": "1", "customDimensions": , "customMetrics": , "productListName": "(not set)", "productListPosition": "0", "productCouponCode": "(not set)"}, "promotion": , "eCommerceAction": {"action_type": "3", "step": "1"}, "experiment": , "customVariables": , "customDimensions": , "customMetrics": , "type": "EVENT", "social": {"socialNetwork": "(not set)", "hasSocialSourceReferral": "No", "socialInteractionNetworkAction": " : "}, "contentGroup": {"contentGroup1": "(not set)", "contentGroup2": "Apparel", "contentGroup3": "(not set)", "contentGroup4": "(not set)", "contentGroup5": "(not set)", "previousContentGroup1": "(entrance)", "previousContentGroup2": "(entrance)", "previousContentGroup3": "(entrance)", "previousContentGroup4": "(entrance)", "previousContentGroup5": "(entrance)"}, "dataSource": "web", "publisher_infos": }, {"hitNumber": "2", "time": "7385", "hour": "12", "minute": "32", "isInteraction": True, "isEntrance": True, "page": {"pagePath": "/basket.html", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Shopping Cart", "pagePathLevel1": "/basket.html", "pagePathLevel2": "", "pagePathLevel3": "", "pagePathLevel4": ""}, "appInfo": {"screenName": "shop.googlemerchandisestore.com/basket.html", "landingScreenName": "shop.googlemerchandisestore.com/google+redesign/apparel/womens/womens+t+shirts", "exitScreenName": "shop.googlemerchandisestore.com/google+redesign/apparel/womens", "screenDepth": "0"}, "exceptionInfo": {"isFatal": True}, "product": , "promotion": , "eCommerceAction": {"action_type": "0", "step": "1"}, "experiment": , "customVariables": , "customDimensions": , "customMetrics": , "type": "PAGE", "social": {"socialNetwork": "(not set)", "hasSocialSourceReferral": "No", "socialInteractionNetworkAction": " : "}, "contentGroup": {"contentGroup1": "(not set)", "contentGroup2": "(not set)", "contentGroup3": "(not set)", "contentGroup4": "(not set)", "contentGroup5": "(not set)", "previousContentGroup1": "(not set)", "previousContentGroup2": "Apparel", "previousContentGroup3": "(not set)", "previousContentGroup4": "(not set)", "previousContentGroup5": "(not set)"}, "dataSource": "web", "publisher_infos": }, {"hitNumber": "3", "time": "17732", "hour": "12", "minute": "32", "isInteraction": True, "referer": "https://www.google.com/", "page": {"pagePath": "/google+redesign/apparel/womens/womens+t+shirts", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Women"s T-Shirts | Apparel | Google Merchandise Store", "pagePathLevel1": "/google+redesign/", "pagePathLevel2": "/apparel/", "pagePathLevel3": "/womens/", "pagePathLevel4": "/womens+t+shirts"}, "transaction": {"currencyCode": "USD"}, "item": {"currencyCode": "USD"}, "appInfo": {"screenName": "shop.googlemerchandisestore.com/google+redesig ...

# %% [markdown]
# We can see that we have nested dictionary so we have to clean it up.

# %%
import re
d = df.loc[:,'hits'].replace("[","").replace("]","").replace("'",'"')
d = d.loc[9,'hits']
d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
d = d.replace("{","").replace("}","").replace('"',"")
length = len(d.split(','))
print(length,d)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-120-393a73fa49fe> in <module>
#       1 import re
#       2 d = df.loc[:,'hits'].replace("[","").replace("]","").replace("'",'"')
# ----> 3 d = d.loc[9,'hits']
#       4 d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
#       5 d = d.replace("{","").replace("}","").replace('"',"")
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1047
#    1048         # no multi-index, so validate all of the indexers
# -> 1049         self._has_valid_tuple(tup)
#    1050
#    1051         # ugly hack for GH #836
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     698         for i, k in enumerate(key):
#     699             if i >= self.ndim:
# --> 700                 raise IndexingError("Too many indexers")
#     701             try:
#     702                 self._validate_key(k, i)
#
# IndexingError: Too many indexers

# %%
# Out:
# 481

# %%
d = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')
d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
length = len(d.split(','))

test={}

for i in range(length):
    d = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')
    d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
    d = d.replace("{","").replace("}","").replace('"',"")
    d = d.split(',')[i].split(':')[-1]
    test[i]=d

# %%
d = df.loc[2,'hits'].replace("[","").replace("]","").replace("'",'"')
d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
d.split(',')[100]
# Out:
# ' {"hitNumber": "3"'

# %%
import re
d = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')
d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
length = len(d.split(','))

hits={}

for i in range(length):
    sum_value={}
    for index in range(2):
        d = df.loc[index,'hits'].replace("[","").replace("]","").replace("'",'"')
        d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
        d = d.replace("{","").replace("}","").replace('"',"")
        d = d.split(',')[i].split(':')[-1]
        sum_value[index]=d
    key = df.loc[i,'hits'].replace("[","").replace("]","").replace("'",'"')
    key = re.sub(' "[a-zA-Z]{2,20}": {' ,"",key)
    key = key.replace("{","").replace("}","").replace('"',"")
    key = key.split(",")[i].split(":")[0]
    hits[key]=sum_value
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-104-24f60e59e019> in <module>
#      12         d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
#      13         d = d.replace("{","").replace("}","").replace('"',"")
# ---> 14         d = d.split(',')[i].split(':')[-1]
#      15         sum_value[index]=d
#      16     key = df.loc[i,'hits'].replace("[","").replace("]","").replace("'",'"')
#
# IndexError: list index out of range

# %%
hits
# Out:
# {'hitNumber': {0: ' 1'},
#  ' time': {0: ' (not set)'},
#  ' hour': {0: ' True'},
#  ' minute': {0: ' Brand Row 7-1'},
#  ' isInteraction': {0: ' shop.googlemerchandisestore.com/home'},
#  ' isEntrance': {0: ' /home'},
#  'pagePath': {0: ' '},
#  ' hostname': {0: ' PAGE'},
#  ' pagePathLevel1': {0: ' mens-tshirts.jpg'},
#  ' pagePathLevel2': {0: ' '},
#  ' pagePathLevel4': {0: ' home_main_link_apparel.jpg'},
#  'screenName': {0: ' '},
#  ' landingScreenName': {0: ' shop.googlemerchandisestore.com'},
#  ' exitScreenName': {0: ' (not set)'},
#  'isFatal': {0: ' (not set)'},
#  ' v2ProductName': {0: ' (not set)'},
#  ' v2ProductCategory': {0: ' '},
#  ' productVariant': {0: ' womens-tshirts.jpg'},
#  ' productBrand': {0: ' Brand Row 7-3'},
#  ' productPrice': {0: ' (not set)'},
#  ' localProductPrice': {0: ' (not set)'},
#  ' isImpression': {0: ' Drinkware'},
#  ' productCouponCode': {0: ' Home'},
#  ' customMetrics': {0: ' (not set)'},
#  ' productListName': {0: ' '},
#  ' productListPosition': {0: ' (not set)'},
#  ' productSKU': {0: ' Mens T-Shirts Row 3-1'},
#  ' experiment': {0: ' '},
#  ' previousContentGroup2': {0: ' home_lower_google_500.jpg'},
#  ' previousContentGroup3': {0: ' Office'},
#  ' previousContentGroup4': {0: ' Row 4 Color Combo'},
#  ' previousContentGroup5': {0: ' green_row_link_to_office.jpg'},
#  ' dataSource': {0: ' YouTube Brand Row 7-2'},
#  ' publisher_infos': {0: ' Category'},
#  ' referer': {0: ' 3352'},
#  ' promoCreative': {0: ' Womens T-Shirts'},
#  ' promoId': {0: ' 4990000'},
#  ' promoName': {0: ' green_row_link_to_office.jpg'},
#  ' promoPosition': {0: ' Brand Row 7-2'},
#  'promoIsView': {0: ' /google+redesign/'},
#  ' step': {0: ' (not set)'},
#  ' customVariables': {0: ' (not set)'},
#  ' type': {0: ' Accessories'},
#  'socialNetwork': {0: ' No'},
#  ' hasSocialSourceReferral': {0: ' True'},
#  ' socialInteractionNetworkAction': {0: ' Womens T-Shirts Row 3-2'},
#  'contentGroup1': {0: ' '},
#  ' contentGroup2': {0: ' '},
#  ' contentGroup3': {0: ' 4'},
#  ' contentGroup4': {0: ' Apparel'},
#  ' customDimensions': {0: ' (not set)'},
#  ' product': {0: ' True'},
#  'promoId': {0: ' Category'},
#  'promoIsClick': {0: ' 3'},
#  'action_type': {0: ' Google Mouse Pad Navy'},
#  ' contentGroup5': {0: ' red_row_hydrate.jpg'},
#  ' hitNumber': {0: ' '},
#  ' screenDepth': {0: ' Mens T-Shirts'},
#  ' contentGroupUniqueViews2': {0: ' Google Laptop and Cell Phone Stickers'},
#  ' promotion': {0: ' web'},
#  'currencyCode': {0: ' /home'},
#  ' pageTitle': {0: ' red_row_hydrate.jpg'},
#  'eventCategory': {0: ' Apparel Row 1'},
#  ' eventLabel': {0: ' (not set)'}}

# %%
d = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')
d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)

import re
length = len(d.split(','))-1

hits={}
for i in range(length):
    sum_value={}
    for index in range(len(df)):
        d = df.loc[index,'hits'].replace("[","").replace("]","").replace("'",'"')
        d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
        d = d.replace("{","").replace("}","")
        value = d.replace('"',"").split(",")[i].split(":")[-1]
        sum_value[index]=value
    key = df.loc[i,'hits'].replace("[","").replace("]","").replace("'",'"')
    key = re.sub(' "[a-zA-Z]{2,20}": {' ,"",key)
    key = key.replace("{","").replace("}","").replace('"',"")
    key = key.split(",")[i].split(":")[0]
    hits[key]=sum_value
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-2ce909aa13bb> in <module>
#      12         d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
#      13         d = d.replace("{","").replace("}","")
# ---> 14         value = d.replace('"',"").split(",")[i].split(":")[-1]
#      15         sum_value[index]=value
#      16     key = df.loc[i,'hits'].replace("[","").replace("]","").replace("'",'"')
#
# IndexError: list index out of range

# %%
t = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')

import re
t = re.findall(' "[a-zA-Z]{2,20}": {' ,t)
t[0].replace('"',"").replace(" ","").replace(":{","")
# Out:
# 'page'

# %%
t = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')

import re
t = re.sub(' "[a-zA-Z]{2,20}": {' ,"",t)
t.replace("{","").replace("}","").replace('"',"").split(",")[1].split(":")[-1]
# Out:
# ' 0'

# %%
d = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')
d = re.sub(' "[a-zA-Z]{2,20}": {' ,"",d)
d.replace("{","").replace("}","").replace('"',"").split(",")[401].split(":")[-1]
# Out:
# ' '

# %%
dict_to_df(hits)

# %%
df.head()
# Out:
#   channelGrouping                            customDimensions      date  \
# 0  Organic Search           [{'index': '4', 'value': 'APAC'}]  20180511
# 1          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 2  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
# 3          Direct  [{'index': '4', 'value': 'North America'}]  20180511
# 4  Organic Search  [{'index': '4', 'value': 'North America'}]  20180511
#
#                                               device        fullVisitorId  \
# 0  {"browser": "Chrome", "browserVersion": "not a...  7460955084541987166
# 1  {"browser": "Chrome", "browserVersion": "not a...   460252456180441002
# 2  {"browser": "Chrome", "browserVersion": "not a...  3461808543879602873
# 3  {"browser": "Chrome", "browserVersion": "not a...   975129477712150630
# 4  {"browser": "Internet Explorer", "browserVersi...  8381672768065729990
#
#                                           geoNetwork  \
# 0  {"continent": "Asia", "subContinent": "Souther...
# 1  {"continent": "Americas", "subContinent": "Nor...
# 2  {"continent": "Americas", "subContinent": "Nor...
# 3  {"continent": "Americas", "subContinent": "Nor...
# 4  {"continent": "Americas", "subContinent": "Nor...
#
#                                                 hits  socialEngagementType  \
# 0  [{'hitNumber': '1', 'time': '0', 'hour': '21',...  Not Socially Engaged
# 1  [{'hitNumber': '1', 'time': '0', 'hour': '11',...  Not Socially Engaged
# 2  [{'hitNumber': '1', 'time': '0', 'hour': '12',...  Not Socially Engaged
# 3  [{'hitNumber': '1', 'time': '0', 'hour': '23',...  Not Socially Engaged
# 4  [{'hitNumber': '1', 'time': '0', 'hour': '10',...  Not Socially Engaged
#
#                                               totals  \
# 0  {"visits": "1", "hits": "4", "pageviews": "3",...
# 1  {"visits": "1", "hits": "4", "pageviews": "3",...
# 2  {"visits": "1", "hits": "4", "pageviews": "3",...
# 3  {"visits": "1", "hits": "5", "pageviews": "4",...
# 4  {"visits": "1", "hits": "5", "pageviews": "4",...
#
#                                        trafficSource     visitId  visitNumber  \
# 0  {"referralPath": "(not set)", "campaign": "(no...  1526099341            2
# 1  {"referralPath": "(not set)", "campaign": "(no...  1526064483          166
# 2  {"referralPath": "(not set)", "campaign": "(no...  1526067157            2
# 3  {"referralPath": "(not set)", "campaign": "(no...  1526107551            4
# 4  {"referralPath": "(not set)", "campaign": "(no...  1526060254            1
#
#    visitStartTime customDimensions_index customDimensions_value  \
# 0      1526099341                      4                   APAC
# 1      1526064483                      4          North America
# 2      1526067157                      4          North America
# 3      1526107551                      4          North America
# 4      1526060254                      4          North America
#
#              browser                 browserVersion  \
# 0             Chrome  not available in demo dataset
# 1             Chrome  not available in demo dataset
# 2             Chrome  not available in demo dataset
# 3             Chrome  not available in demo dataset
# 4  Internet Explorer  not available in demo dataset
#
#                      browserSize operatingSystem  \
# 0  not available in demo dataset         Android
# 1  not available in demo dataset       Macintosh
# 2  not available in demo dataset       Chrome OS
# 3  not available in demo dataset             iOS
# 4  not available in demo dataset         Windows
#
#           operatingSystemVersion  isMobile           mobileDeviceBranding  \
# 0  not available in demo dataset      True  not available in demo dataset
# 1  not available in demo dataset     False  not available in demo dataset
# 2  not available in demo dataset     False  not available in demo dataset
# 3  not available in demo dataset      True  not available in demo dataset
# 4  not available in demo dataset      True  not available in demo dataset
#
#                mobileDeviceModel            mobileInputSelector  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                 mobileDeviceInfo      mobileDeviceMarketingName  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     flashVersion                       language  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#                     screenColors               screenResolution  \
# 0  not available in demo dataset  not available in demo dataset
# 1  not available in demo dataset  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3  not available in demo dataset  not available in demo dataset
# 4  not available in demo dataset  not available in demo dataset
#
#   deviceCategory continent      subContinent        country  \
# 0         mobile      Asia     Southern Asia          India
# 1        desktop  Americas  Northern America  United States
# 2        desktop  Americas  Northern America  United States
# 3         mobile  Americas  Northern America  United States
# 4         tablet  Americas  Northern America  United States
#
#                           region                              metro  \
# 0                          Delhi                          (not set)
# 1                     California  San Francisco-Oakland-San Jose CA
# 2  not available in demo dataset      not available in demo dataset
# 3                          Texas                         Houston TX
# 4                     California                     Los Angeles CA
#
#                             city                         cityId  \
# 0                      (not set)  not available in demo dataset
# 1                  San Francisco  not available in demo dataset
# 2  not available in demo dataset  not available in demo dataset
# 3                        Houston  not available in demo dataset
# 4                         Irvine  not available in demo dataset
#
#              networkDomain                       latitude  \
# 0          unknown.unknown  not available in demo dataset
# 1                (not set)  not available in demo dataset
# 2  onlinecomputerworks.com  not available in demo dataset
# 3                (not set)  not available in demo dataset
# 4                      com  not available in demo dataset
#
#                        longitude                networkLocation "hitNumber"  \
# 0  not available in demo dataset  not available in demo dataset         "1"
# 1  not available in demo dataset  not available in demo dataset         "1"
# 2  not available in demo dataset  not available in demo dataset         "1"
# 3  not available in demo dataset  not available in demo dataset         "1"
# 4  not available in demo dataset  not available in demo dataset         "1"
#
#    "time"  "hour"  "minute"  "isInteraction"  "isEntrance"  \
# 0     "0"    "21"      "29"             True    "pagePath"
# 1     "0"    "11"      "48"             True          True
# 2     "0"    "12"      "32"             True        "https
# 3     "0"    "23"      "45"             True          True
# 4     "0"    "10"      "37"             True          True
#
#                                "page"  \
# 0                              "Home"
# 1   "shop.googlemerchandisestore.com"
# 2   "shop.googlemerchandisestore.com"
# 3                          "pagePath"
# 4                          "pagePath"
#
#                                           "hostname"  ...  \
# 0                                            "/home"  ...
# 1                                             "Home"  ...
# 2   "Women"s T-Shirts | Apparel | Google Merchand...  ...
# 3                  "shop.googlemerchandisestore.com"  ...
# 4                  "shop.googlemerchandisestore.com"  ...
#
#               "productBrand"             "productPrice"  \
# 0              "action_type"                        "1"
# 1   "home_bags_google_2.jpg"              "Row 2 Combo"
# 2                "(not set)"                "(not set)"
# 3                "Backpacks"   "home_bags_google_2.jpg"
# 4                "Backpacks"   "home_bags_google_2.jpg"
#
#         "localProductPrice"            "isImpression"    "productCouponCode"  \
# 0                                                                       "No"
# 1   "Mens T-Shirts Row 3-1"           "Mens T-Shirts"   "womens-tshirts.jpg"
# 2                "21990000"                "21990000"                    "0"
# 3             "Row 2 Combo"   "Mens T-Shirts Row 3-1"      "Womens T-Shirts"
# 4             "Row 2 Combo"   "Mens T-Shirts Row 3-1"      "Womens T-Shirts"
#
#        "customMetrics"           "productListName"  \
# 0                                          "EVENT"
# 1            "Row 3-1"   "Womens T-Shirts Row 3-2"
# 2
# 3   "mens-tshirts.jpg"                   "Row 3-1"
# 4   "mens-tshirts.jpg"                   "Row 3-1"
#
#         "productListPosition"           "productSKU"  \
# 0             "socialNetwork"                     "
# 1           "Womens T-Shirts"              "Row 3-2"
# 2                 "(not set)"            "(not set)"
# 3   "Womens T-Shirts Row 3-2"   "womens-tshirts.jpg"
# 4   "Womens T-Shirts Row 3-2"   "womens-tshirts.jpg"
#
#                   "experiment"          "previousContentGroup2"  \
# 0                  "(not set)"                      "(not set)"
# 1                     "Office"   "green_row_link_to_office.jpg"
# 2                "action_type"                              "1"
# 3   "Office Row 5 Color Combo"                         "Office"
# 4   "Office Row 5 Color Combo"                         "Office"
#
#            "previousContentGroup3"         "previousContentGroup4"  \
# 0                      "(not set)"                     "(not set)"
# 1              "Row 5 Color Combo"   "Drinkware Row 4 Color Combo"
# 2
# 3   "green_row_link_to_office.jpg"             "Row 5 Color Combo"
# 4   "green_row_link_to_office.jpg"             "Row 5 Color Combo"
#
#           "previousContentGroup5"            "dataSource"  \
# 0                    "(entrance)"            "(entrance)"
# 1                     "Drinkware"   "red_row_hydrate.jpg"
# 2
# 3   "Drinkware Row 4 Color Combo"             "Drinkware"
# 4   "Drinkware Row 4 Color Combo"             "Drinkware"
#
#         "publisher_infos" hitNumber  time  hour  minute  isInteraction  \
# 0            "(entrance)"         1     0    21      29           True
# 1     "Row 4 Color Combo"         1     0    11      48           True
# 2                 "EVENT"         1     0    12      32           True
# 3   "red_row_hydrate.jpg"         1     0    23      45           True
# 4   "red_row_hydrate.jpg"         1     0    10      37           True
#
#    isEntrance                              page  \
# 0    pagePath                              Home
# 1        True   shop.googlemerchandisestore.com
# 2       https   shop.googlemerchandisestore.com
# 3        True                          pagePath
# 4        True                          pagePath
#
#                                             hostname  pagePathLevel1  \
# 0                                              /home
# 1                                               Home
# 2   Womens T-Shirts | Apparel | Google Merchandis...       /apparel/
# 3                    shop.googlemerchandisestore.com           /home
# 4                    shop.googlemerchandisestore.com           /home
#
#    pagePathLevel2                         pagePathLevel4  \
# 0                   shop.googlemerchandisestore.com/home
# 1                                             screenName
# 2        /womens/                           currencyCode
# 3
# 4
#
#                                  appInfo  \
# 0   shop.googlemerchandisestore.com/home
# 1   shop.googlemerchandisestore.com/home
# 2                           currencyCode
# 3                             screenName
# 4                             screenName
#
#                                    landingScreenName    exitScreenName  \
# 0                                      eventCategory   Promotion Click
# 1                                            isFatal
# 2   shop.googlemerchandisestore.com/google+redesi...                 0
# 3                                                  0           isFatal
# 4                                                  0           isFatal
#
#     exceptionInfo              v2ProductName       v2ProductCategory  \
# 0         promoId              contentGroup1          Category Row 2
# 1         Apparel   Office Row 5 Color Combo   Backpacks Row 2 Combo
# 2   eventCategory                                   Google Tee White
# 3         promoId                    Row 3-2                   Row 1
# 4         promoId                    Row 3-2                   Row 1
#
#                           productVariant             productBrand  \
# 0                           promoIsClick              action_type
# 1                              Backpacks   home_bags_google_2.jpg
# 2   Home/Apparel/Womens/Womens-T-Shirts/                (not set)
# 3                  Backpacks Row 2 Combo                Backpacks
# 4                  Backpacks Row 2 Combo                Backpacks
#
#               productPrice       localProductPrice            isImpression  \
# 0                        1
# 1              Row 2 Combo   Mens T-Shirts Row 3-1           Mens T-Shirts
# 2                (not set)                21990000                21990000
# 3   home_bags_google_2.jpg             Row 2 Combo   Mens T-Shirts Row 3-1
# 4   home_bags_google_2.jpg             Row 2 Combo   Mens T-Shirts Row 3-1
#
#      productCouponCode      customMetrics           productListName  \
# 0                   No                                        EVENT
# 1   womens-tshirts.jpg            Row 3-1   Womens T-Shirts Row 3-2
# 2                    0
# 3      Womens T-Shirts   mens-tshirts.jpg                   Row 3-1
# 4      Womens T-Shirts   mens-tshirts.jpg                   Row 3-1
#
#         productListPosition           productSKU                 experiment  \
# 0             socialNetwork                                       (not set)
# 1           Womens T-Shirts              Row 3-2                     Office
# 2                 (not set)            (not set)                action_type
# 3   Womens T-Shirts Row 3-2   womens-tshirts.jpg   Office Row 5 Color Combo
# 4   Womens T-Shirts Row 3-2   womens-tshirts.jpg   Office Row 5 Color Combo
#
#            previousContentGroup2          previousContentGroup3  \
# 0                      (not set)                      (not set)
# 1   green_row_link_to_office.jpg              Row 5 Color Combo
# 2                              1
# 3                         Office   green_row_link_to_office.jpg
# 4                         Office   green_row_link_to_office.jpg
#
#           previousContentGroup4         previousContentGroup5  \
# 0                     (not set)                    (entrance)
# 1   Drinkware Row 4 Color Combo                     Drinkware
# 2
# 3             Row 5 Color Combo   Drinkware Row 4 Color Combo
# 4             Row 5 Color Combo   Drinkware Row 4 Color Combo
#
#              dataSource       publisher_infos
# 0            (entrance)            (entrance)
# 1   red_row_hydrate.jpg     Row 4 Color Combo
# 2                                       EVENT
# 3             Drinkware   red_row_hydrate.jpg
# 4             Drinkware   red_row_hydrate.jpg
#
# [5 rows x 110 columns]

# %%
df.loc[3,'hits'].replace("[","").replace("]","").replace("'",'"').replace("{","").replace("}","")
# Out:
# '"hitNumber": "1", "time": "0", "hour": "23", "minute": "45", "isInteraction": True, "isEntrance": True, "referer": "https://www.googlemerchandisestore.com/", "page": "pagePath": "/home", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Home", "pagePathLevel1": "/home", "pagePathLevel2": "", "pagePathLevel3": "", "pagePathLevel4": "", "appInfo": "screenName": "shop.googlemerchandisestore.com/home", "landingScreenName": "shop.googlemerchandisestore.com/home", "exitScreenName": "shop.googlemerchandisestore.com/google+redesign/apparel/mens/quickview", "screenDepth": "0", "exceptionInfo": "isFatal": True, "product": , "promotion": "promoId": "Apparel Row 1", "promoName": "Apparel", "promoCreative": "home_main_link_apparel.jpg", "promoPosition": "Row 1", "promoId": "Backpacks Row 2 Combo", "promoName": "Backpacks", "promoCreative": "home_bags_google_2.jpg", "promoPosition": "Row 2 Combo", "promoId": "Mens T-Shirts Row 3-1", "promoName": "Mens T-Shirts", "promoCreative": "mens-tshirts.jpg", "promoPosition": "Row 3-1", "promoId": "Womens T-Shirts Row 3-2", "promoName": "Womens T-Shirts", "promoCreative": "womens-tshirts.jpg", "promoPosition": "Row 3-2", "promoId": "Office Row 5 Color Combo", "promoName": "Office", "promoCreative": "green_row_link_to_office.jpg", "promoPosition": "Row 5 Color Combo", "promoId": "Drinkware Row 4 Color Combo", "promoName": "Drinkware", "promoCreative": "red_row_hydrate.jpg", "promoPosition": "Row 4 Color Combo", "promoId": "Google Brand Row 7-1", "promoName": "Google Brand", "promoCreative": "home_lower_google_500.jpg", "promoPosition": "Brand Row 7-1", "promoId": "YouTube Brand Row 7-2", "promoName": "YouTube Brand", "promoCreative": "home_lower_youtube_500.jpg", "promoPosition": "Brand Row 7-2", "promoId": "Android Brand Row 7-3", "promoName": "Andriod Brand", "promoCreative": "home_lower_android_500.jpg", "promoPosition": "Brand Row 7-3", "promotionActionInfo": "promoIsView": True, "eCommerceAction": "action_type": "0", "step": "1", "experiment": , "customVariables": , "customDimensions": , "customMetrics": , "type": "PAGE", "social": "socialNetwork": "(not set)", "hasSocialSourceReferral": "No", "socialInteractionNetworkAction": " : ", "contentGroup": "contentGroup1": "(not set)", "contentGroup2": "(not set)", "contentGroup3": "(not set)", "contentGroup4": "(not set)", "contentGroup5": "(not set)", "previousContentGroup1": "(entrance)", "previousContentGroup2": "(entrance)", "previousContentGroup3": "(entrance)", "previousContentGroup4": "(entrance)", "previousContentGroup5": "(entrance)", "dataSource": "web", "publisher_infos": , "hitNumber": "2", "time": "5739", "hour": "23", "minute": "45", "isInteraction": True, "page": "pagePath": "/google+redesign/apparel", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Apparel | Google Merchandise Store", "pagePathLevel1": "/google+redesign/", "pagePathLevel2": "/apparel", "pagePathLevel3": "", "pagePathLevel4": "", "transaction": "currencyCode": "USD", "item": "currencyCode": "USD", "appInfo": "screenName": "shop.googlemerchandisestore.com/google+redesign/apparel", "landingScreenName": "shop.googlemerchandisestore.com/home", "exitScreenName": "shop.googlemerchandisestore.com/google+redesign/apparel/mens/quickview", "screenDepth": "0", "exceptionInfo": "isFatal": True, "product": "productSKU": "GGOEGAMQ088099", "v2ProductName": "Google Cappy Bib White", "v2ProductCategory": "Home/Apparel/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "13990000", "localProductPrice": "13990000", "isImpression": True, "customDimensions": , "customMetrics": , "productListName": "Category", "productListPosition": "1", "productCouponCode": "(not set)", "productSKU": "GGOEGAMR088499", "v2ProductName": "Google Standard Bib Red", "v2ProductCategory": "Home/Apparel/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "13990000", "localProductPrice": "13990000", "isImpression": True, "customDimensions": ...

# %%
d = df.loc[0,'hits'].replace("[","").replace("]","").replace("'",'"')
d.replace('"',"").split(",")[7].split(":")[1]
# Out:
# ' Home'

# %%
d
# Out:
# '{"hitNumber": "1", "time": "0", "hour": "21", "minute": "29", "isInteraction": True, "page": {"pagePath": "/home", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Home", "pagePathLevel1": "/home", "pagePathLevel2": "", "pagePathLevel3": "", "pagePathLevel4": ""}, "appInfo": {"screenName": "shop.googlemerchandisestore.com/home", "landingScreenName": "shop.googlemerchandisestore.com/home", "exitScreenName": "shop.googlemerchandisestore.com/home", "screenDepth": "0"}, "exceptionInfo": {"isFatal": True}, "eventInfo": {"eventCategory": "Enhanced Ecommerce", "eventAction": "Promotion Click"}, "product": , "promotion": {"promoId": "Category Row 2", "promoName": "Accessories", "promoCreative": "toy.png", "promoPosition": "Category Row 2"}, "promotionActionInfo": {"promoIsClick": True}, "eCommerceAction": {"action_type": "0", "step": "1"}, "experiment": , "customVariables": , "customDimensions": , "customMetrics": , "type": "EVENT", "social": {"socialNetwork": "(not set)", "hasSocialSourceReferral": "No", "socialInteractionNetworkAction": " : "}, "contentGroup": {"contentGroup1": "(not set)", "contentGroup2": "(not set)", "contentGroup3": "(not set)", "contentGroup4": "(not set)", "contentGroup5": "(not set)", "previousContentGroup1": "(entrance)", "previousContentGroup2": "(entrance)", "previousContentGroup3": "(entrance)", "previousContentGroup4": "(entrance)", "previousContentGroup5": "(entrance)"}, "dataSource": "web", "publisher_infos": }, {"hitNumber": "2", "time": "3352", "hour": "21", "minute": "29", "isInteraction": True, "isEntrance": True, "page": {"pagePath": "/google+redesign/accessories", "hostname": "shop.googlemerchandisestore.com", "pageTitle": "Accessories | Google Merchandise Store", "pagePathLevel1": "/google+redesign/", "pagePathLevel2": "/accessories", "pagePathLevel3": "", "pagePathLevel4": ""}, "transaction": {"currencyCode": "USD"}, "item": {"currencyCode": "USD"}, "appInfo": {"screenName": "shop.googlemerchandisestore.com/google+redesign/accessories", "landingScreenName": "shop.googlemerchandisestore.com/home", "exitScreenName": "shop.googlemerchandisestore.com/home", "screenDepth": "0"}, "exceptionInfo": {"isFatal": True}, "product": {"productSKU": "GGOEAKDH019899", "v2ProductName": "Windup Android", "v2ProductCategory": "Home/Accessories/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "3990000", "localProductPrice": "3990000", "isImpression": True, "customDimensions": , "customMetrics": , "productListName": "Category", "productListPosition": "1", "productCouponCode": "(not set)"}, {"productSKU": "GGOEGFSR022099", "v2ProductName": "Google Mini Kick Ball", "v2ProductCategory": "Home/Accessories/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "1990000", "localProductPrice": "1990000", "isImpression": True, "customDimensions": , "customMetrics": , "productListName": "Category", "productListPosition": "2", "productCouponCode": "(not set)"}, {"productSKU": "GGOEGEBK094499", "v2ProductName": "Google Bot", "v2ProductCategory": "Home/Accessories/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "9990000", "localProductPrice": "9990000", "isImpression": True, "customDimensions": , "customMetrics": , "productListName": "Category", "productListPosition": "3", "productCouponCode": "(not set)"}, {"productSKU": "GGOEGPJC019099", "v2ProductName": "7&quot; Dog Frisbee", "v2ProductCategory": "Home/Accessories/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "1500000", "localProductPrice": "1500000", "isImpression": True, "customDimensions": , "customMetrics": , "productListName": "Category", "productListPosition": "4", "productCouponCode": "(not set)"}, {"productSKU": "GGOEAFKA087499", "v2ProductName": "Android Small Removable Sticker Sheet", "v2ProductCategory": "Home/Accessories/", "productVariant": "(not set)", "productBrand": "(not set)", "productPrice": "2990000", "localProductPrice": "29 ...
